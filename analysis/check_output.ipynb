# %%
import pandas as pd

# %%
df = pd.read_csv("../output/dataset_patients_2024-02-01.csv.gz")
df.head(10)
# Out:
#    patient_id  start_date  index_date registered_start registered_index alive  \
# 0           1  2024-02-01  2024-03-01                T                T     T
# 1           2  2024-02-01  2024-03-01                T                T     T
# 2           3  2024-02-01  2024-03-01                T                T     T
# 3           4  2024-02-01  2024-03-01                T                T     T
# 4           5  2024-02-01  2024-03-01                T                T     T
# 5           6  2024-02-01  2024-03-01                T                T     T
# 6           7  2024-02-01  2024-03-01                T                T     T
# 7           8  2024-02-01  2024-03-01                T                T     T
# 8           9  2024-02-01  2024-03-01                T                T     T
# 9          10  2024-02-01  2024-03-01                T                T     T
#
#        sex  age                 imd                ethnicity  ...  \
# 0  unknown   91             Missing              Other White  ...
# 1   female   95             Missing              Other White  ...
# 2     male   62             Missing              Other White  ...
# 3  unknown  108             Missing  All other ethnic groups  ...
# 4     male    7                   4  All other ethnic groups  ...
# 5     male   89             Missing                  Missing  ...
# 6     male   44  5 (Least Deprived)      White and Caribbean  ...
# 7     male   99             Missing                  Missing  ...
# 8   female   58                   3              Bangladeshi  ...
# 9     male   61             Missing                  African  ...
#
#    recurrent_uti_12m recurrent_uti include_patient_otitis_media  \
# 0                  F             F                            F
# 1                  F             F                            F
# 2                  F             F                            F
# 3                  F             F                            F
# 4                  F             F                            T
# 5                  F             F                            F
# 6                  F             F                            F
# 7                  F             F                            F
# 8                  F             F                            F
# 9                  F             F                            F
#
#   include_patient_sinusitis include_patient_sore_throat  \
# 0                         T                           T
# 1                         T                           T
# 2                         T                           T
# 3                         T                           T
# 4                         F                           T
# 5                         T                           T
# 6                         T                           T
# 7                         T                           T
# 8                         T                           T
# 9                         T                           T
#
#   include_patient_insect_bites include_patient_shingles  \
# 0                            T                        T
# 1                            T                        T
# 2                            T                        T
# 3                            T                        T
# 4                            T                        F
# 5                            T                        T
# 6                            T                        T
# 7                            T                        T
# 8                            T                        T
# 9                            T                        T
#
#   include_patient_impetigo include_patient_uuti  \
# 0                        T                    F
# 1                        T                    F
# 2                        T                    F
# 3                        T                    F
# 4                        T                    F
# 5                        T                    F
# 6                        T                    F
# 7                        T                    F
# 8                        T                    T
# 9                        T                    F
#
#   include_patient_overall_eligible
# 0                                T
# 1                                T
# 2                                T
# 3                                T
# 4                                T
# 5                                T
# 6                                T
# 7                                T
# 8                                T
# 9                                T
#
# [10 rows x 36 columns]

# %%
df2 = pd.read_csv("../output/dataset_patients_2024-03-01.csv.gz")
df2.head(10)
# Out:
#    patient_id  start_date  index_date registered_start registered_index alive  \
# 0           1  2024-03-01  2024-04-01                T                T     T
# 1           2  2024-03-01  2024-04-01                T                T     T
# 2           3  2024-03-01  2024-04-01                T                T     T
# 3           4  2024-03-01  2024-04-01                T                T     T
# 4           5  2024-03-01  2024-04-01                T                T     T
# 5           6  2024-03-01  2024-04-01                T                T     T
# 6           7  2024-03-01  2024-04-01                T                T     T
# 7           8  2024-03-01  2024-04-01                T                T     T
# 8           9  2024-03-01  2024-04-01                T                T     T
# 9          10  2024-03-01  2024-04-01                T                T     T
#
#        sex  age                 imd                ethnicity  ...  \
# 0  unknown   91             Missing              Other White  ...
# 1   female   95             Missing              Other White  ...
# 2     male   61             Missing              Other White  ...
# 3  unknown  108             Missing  All other ethnic groups  ...
# 4     male    6                   4  All other ethnic groups  ...
# 5     male   88             Missing                  Missing  ...
# 6     male   44  5 (Least Deprived)      White and Caribbean  ...
# 7     male  100             Missing                  Missing  ...
# 8   female   61             Missing              Bangladeshi  ...
# 9     male   60             Missing                  African  ...
#
#    recurrent_uti_12m recurrent_uti include_patient_otitis_media  \
# 0                  F             F                            F
# 1                  F             F                            F
# 2                  F             F                            F
# 3                  F             F                            F
# 4                  F             F                            T
# 5                  F             F                            F
# 6                  F             F                            F
# 7                  F             F                            F
# 8                  F             F                            F
# 9                  F             F                            F
#
#   include_patient_sinusitis include_patient_sore_throat  \
# 0                         T                           T
# 1                         T                           T
# 2                         T                           T
# 3                         T                           T
# 4                         F                           T
# 5                         T                           T
# 6                         T                           T
# 7                         T                           T
# 8                         T                           T
# 9                         T                           T
#
#   include_patient_insect_bites include_patient_shingles  \
# 0                            T                        T
# 1                            T                        T
# 2                            T                        T
# 3                            T                        T
# 4                            T                        F
# 5                            T                        T
# 6                            T                        T
# 7                            T                        T
# 8                            T                        T
# 9                            T                        T
#
#   include_patient_impetigo include_patient_uuti  \
# 0                        T                    F
# 1                        T                    F
# 2                        T                    F
# 3                        T                    F
# 4                        T                    F
# 5                        T                    F
# 6                        T                    F
# 7                        T                    F
# 8                        T                    T
# 9                        T                    F
#
#   include_patient_overall_eligible
# 0                                T
# 1                                T
# 2                                T
# 3                                T
# 4                                T
# 5                                T
# 6                                T
# 7                                T
# 8                                T
# 9                                T
#
# [10 rows x 36 columns]

# %% [markdown]
# Question: why patient_id 9 - age 58 -> 61?
